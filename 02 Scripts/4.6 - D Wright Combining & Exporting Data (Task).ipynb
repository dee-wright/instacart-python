# %% [markdown]
# # TOC
# 1. Prep & Import
# 2. Merge datasets
# 3. Check new dataset
# 4. Export new merged dataset as pickle

# %% [markdown]
# ### Prep

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing data
path = r'C:\Users\Ryzen RGB Madness!!!\Instacart Basket Analysis'

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Cleaned', 'products_cleaned.csv'))

# %%
df_prods
# Out:
#        product_id                                       product_name  \
# 0               1                         Chocolate Sandwich Cookies
# 1               2                                   All-Seasons Salt
# 2               3               Robust Golden Unsweetened Oolong Tea
# 3               4  Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4               5                          Green Chile Anytime Sauce
# ...           ...                                                ...
# 49667       49684          Vodka, Triple Distilled, Twist of Vanilla
# 49668       49685                 En Croute Roast Hazelnut Cranberry
# 49669       49686                                   Artisan Baguette
# 49670       49687         Smartblend Healthy Metabolism Dry Cat Food
# 49671       49688                             Fresh Foaming Cleanser
#
#        aisle_id  department_id  prices
# 0            61             19     5.8
# 1           104             13     9.3
# ...

# %% [markdown]
# #### 4.6.3 - Importing Pickle

# %%
df_ords_prods = pd.read_pickle(os.path.join(path, '02 Data', 'Cleaned', 'orders_products_combined.pkl'))

# %% [markdown]
# #### 4.6.4 - Checking Imported Dataframe

# %%
df_ords_prods.shape
# Out:
# (32434489, 10)

# %% [markdown]
# #### 4.6.5 - Merging df_prods & df_ords_prods

# %%
# Merging dataframes on product_id column
orders_products_merged = df_ords_prods.merge(df_prods, on='product_id')

# %%
orders_products_merged.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2398795        1             2                  3                  7
# 2    473747        1             3                  3                 12
# 3   2254736        1             4                  4                  7
# 4    431534        1             5                  4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     NaN         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#   product_name  aisle_id  department_id  prices
# ...

# %%
# Checking merge rates - inner
orders_products_merged['_merge'].value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
orders_products_merged_outer = df_ords_prods.merge(df_prods, on='product_id', how='outer')

# %%
# Checking merge rates - outer
orders_products_merged_outer['_merge'].value_counts()
# Out:
# _merge
# both          32435059
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %% [markdown]
# #### 4.6.7 - Exporting new dataframe

# %%
# Removing _merge flag for tidiness
orders_products_merged.drop(columns='_merge')
# Out:
#           order_id  user_id  order_number  order_day_of_week  \
# 0          2539329        1             1                  2
# 1          2398795        1             2                  3
# 2           473747        1             3                  3
# 3          2254736        1             4                  4
# 4           431534        1             5                  4
# ...            ...      ...           ...                ...
# 32404854   1320836   202557            17                  2
# 32404855     31526   202557            18                  5
# 32404856    758936   203436             1                  2
# 32404857   2745165   203436             2                  3
# 32404858   3093936   205420             1                  4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
# Exporting merged dataframe as pickle due to size
orders_products_merged.to_pickle(os.path.join(path, '02 Data', 'Cleaned', 'orders_products_merged.pkl'))
